# %% [markdown]
# <a href="https://colab.research.google.com/github/gramelon2003/Python_ptdl/blob/master/python_%C4%91ths.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from matplotlib import pyplot as plt
x = np.linspace(-6, 5, num = 1500)
y = x**3 + 3*x + 7
y1 = 3*x**2 + 3
y2 = 6*x

fig, ax = plt.subplots()
ax.plot(x, y, color = "blue", label = "y(x)")
ax.plot(x, y1, color = "red", label = "y'(x)")
ax.plot(x, y2, color = "green", label = 'y"(x)')
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.legend()

# %%
from matplotlib import pyplot as plt
import numpy as np
x = np.linspace(0, 2 * np.pi, 400)
y = np.sin(x ** 2)
fig, ax = plt.subplots()
ax.plot(x, y)
ax.set_title('A single plot')
# Out:
# Text(0.5, 1.0, 'A single plot')
